# %%
import pandas as pd
import numpy as np
from pathlib import Path

# مسیر اصلی دیتاست (در روت پروژه)
dataset_dir = Path("../Dataset")

target_folders = [
    "ABSA_KPI",
    "Feature_KPI_output",
    "Cleaned_output",
]

print("🚀 شروع اسکن جامع کیفیت داده‌ها (Data Quality Auto-Scanner)...\n")

for folder_name in target_folders:
    folder_path = dataset_dir / folder_name

    if not folder_path.exists():
        continue

    print("\n" + "=" * 75)
    print(f"📂 در حال بازرسی پوشه: {folder_name}")
    print("=" * 75)

    # پیدا کردن تمام فایل‌های Parquet
    parquet_files = list(folder_path.rglob("*.parquet"))

    # برای جلوگیری از طولانی شدن خروجی در پوشه‌های پارت‌بندی‌شده،
    # فقط part_0000.parquet بررسی می‌شود.
    for file_path in parquet_files:

        if (
            "part_" in file_path.name
            and file_path.name != "part_0000.parquet"
        ):
            continue

        try:
            df = pd.read_parquet(file_path)

            if df.empty:
                print(
                    f"⚠️ فایل {file_path.parent.name}/{file_path.name} کاملاً خالی است!"
                )
                continue

            print(f"\n📄 گزارش فایل: {file_path.parent.name} / {file_path.name}")
            print(f"📏 ابعاد: {df.shape[0]:,} سطر و {df.shape[1]} ستون")

            # =====================================================
            # 1. بررسی مقادیر گمشده (Null / NaN)
            # =====================================================
            missing_stats = df.isna().sum()
            missing_cols = missing_stats[missing_stats > 0]

            if not missing_cols.empty:
                print("🚨 مقادیر گمشده (Null):")

                for col, count in missing_cols.items():
                    percent = (count / len(df)) * 100
                    print(
                        f"   - ستون '{col}': {count:,} رکورد ({percent:.1f}%)"
                    )
            else:
                print("✅ هیچ مقدار گمشده‌ای وجود ندارد.")

            # =====================================================
            # 2. بررسی ردیف‌های کاملاً تکراری
            # =====================================================
            duplicate_count = df.duplicated().sum()

            if duplicate_count > 0:
                print(
                    f"🔁 تعداد {duplicate_count:,} ردیف کاملاً تکراری یافت شد!"
                )

            # =====================================================
            # 3. بررسی مقادیر بی‌نهایت (Infinity)
            # =====================================================
            numeric_cols = df.select_dtypes(include=[np.number]).columns

            for col in numeric_cols:
                inf_count = np.isinf(df[col]).sum()

                if inf_count > 0:
                    print(
                        f"♾️ هشدار: ستون '{col}' دارای {inf_count:,} مقدار بی‌نهایت است!"
                    )

            # =====================================================
            # 4. بررسی قوانین منطقی (Logical Checks)
            # =====================================================

            # خرید نباید بیشتر از بازدید باشد
            if (
                "is_purchase" in df.columns
                and "is_view" in df.columns
            ):
                invalid_funnel = df[
                    df["is_purchase"] > df["is_view"]
                ]

                if not invalid_funnel.empty:
                    print(
                        f"❌ خطای منطقی: {len(invalid_funnel):,} رکورد، خرید بیشتر از بازدید دارند!"
                    )

            # امتیاز محصولات باید بین 0 تا 100 باشد
            if "Rate" in df.columns:
                invalid_product_rate = df[
                    (df["Rate"] < 0)
                    | (df["Rate"] > 100)
                ]

                if not invalid_product_rate.empty:
                    print(
                        f"❌ خطای منطقی: {len(invalid_product_rate):,} محصول با امتیاز نامعتبر (خارج از بازه 0 تا 100)!"
                    )

            # امتیاز کامنت‌ها باید بین 0 تا 5 باشد
            if "rate" in df.columns:
                invalid_comment_rate = df[
                    (df["rate"] < 0)
                    | (df["rate"] > 5)
                ]

                if not invalid_comment_rate.empty:
                    print(
                        f"❌ خطای منطقی: {len(invalid_comment_rate):,} کامنت با امتیاز نامعتبر (خارج از بازه 0 تا 5)!"
                    )

            # قیمت نباید منفی باشد
            if "Price" in df.columns:
                invalid_price = df[df["Price"] < 0]

                if not invalid_price.empty:
                    print(
                        f"❌ خطای منطقی: {len(invalid_price):,} محصول با قیمت منفی یافت شد!"
                    )

            # بررسی event_type
            if "event_type" in df.columns:
                valid_events = [
                    "view",
                    "add_to_cart",
                    "purchase",
                ]

                invalid_events = df[
                    ~df["event_type"].isin(valid_events)
                ]

                if not invalid_events.empty:
                    print(
                        f"❌ خطای منطقی: {len(invalid_events):,} رکورد با event_type ناشناخته!"
                    )

        except Exception as e:
            print(f"⚠️ خطا در پردازش {file_path.name}: {e}")

print("\n🎉 اسکنر کیفیت داده‌ها کار خود را با موفقیت به پایان رساند!")
# Out:
# 🚀 شروع اسکن جامع کیفیت داده‌ها (Data Quality Auto-Scanner)...
#
#
# ===========================================================================
# 📂 در حال بازرسی پوشه: ABSA_KPI
# ===========================================================================
#
# 📄 گزارش فایل: ABSA_KPI / aspect_frequency.parquet
# 📏 ابعاد: 255,076 سطر و 2 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: ABSA_KPI / aspect_kpi.parquet
# 📏 ابعاد: 255,076 سطر و 6 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: ABSA_KPI / brand_kpi.parquet
# 📏 ابعاد: 6,641 سطر و 6 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: ABSA_KPI / category_kpi.parquet
# 📏 ابعاد: 195 سطر و 6 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: ABSA_KPI / product_aspect_kpi.parquet
# 📏 ابعاد: 2,129,962 سطر و 7 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: ABSA_KPI / product_kpi.parquet
# 📏 ابعاد: 331,599 سطر و 8 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'top_aspect': 60,005 رکورد (18.1%)
#    - ستون 'worst_aspect': 169,050 رکورد (51.0%)
#
# 📄 گزارش فایل: ABSA_KPI / product_master_absa.parquet
# 📏 ابعاد: 948,352 سطر و 16 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'Category2': 181,346 رکورد (19.1%)
#    - ستون 'positive': 616,753 رکورد (65.0%)
#    - ستون 'negative': 616,753 رکورد (65.0%)
#    - ستون 'neutral': 616,753 رکورد (65.0%)
#    - ستون 'sentiment_score': 616,753 رکورد (65.0%)
#    - ستون 'total_comments': 616,753 رکورد (65.0%)
#    - ستون 'top_aspect': 676,758 رکورد (71.4%)
#    - ستون 'worst_aspect': 785,803 رکورد (82.9%)
#
# 📄 گزارش فایل: ABSA_KPI / sentiment_distribution.parquet
# 📏 ابعاد: 3 سطر و 2 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# ===========================================================================
# 📂 در حال بازرسی پوشه: Feature_KPI_output
# ===========================================================================
#
# 📄 گزارش فایل: Feature_KPI_output / city_features.parquet
# 📏 ابعاد: 20 سطر و 3 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: Feature_KPI_output / comment_features.parquet
# 📏 ابعاد: 331,599 سطر و 5 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: Feature_KPI_output / feature_table.parquet
# 📏 ابعاد: 3,750,416 سطر و 44 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'Category2': 271,786 رکورد (7.2%)
#    - ستون 'Seller': 558 رکورد (0.0%)
#    - ستون 'product_id_comment': 2,492,430 رکورد (66.5%)
#    - ستون 'avg_rate': 2,492,430 رکورد (66.5%)
#    - ستون 'comment_count': 2,492,430 رکورد (66.5%)
#    - ستون 'avg_like_ratio': 2,492,430 رکورد (66.5%)
#    - ستون 'avg_sentiment': 2,492,430 رکورد (66.5%)
# ❌ خطای منطقی: 328,291 رکورد، خرید بیشتر از بازدید دارند!
# ❌ خطای منطقی: 119,087 رکورد با event_type ناشناخته!
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_category_top_categories.parquet
# 📏 ابعاد: 228 سطر و 1 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
# 🔁 تعداد 77 ردیف کاملاً تکراری یافت شد!
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_product_best_funnel_products.parquet
# 📏 ابعاد: 10 سطر و 27 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'product_id_comment': 4 رکورد (40.0%)
#    - ستون 'avg_rate': 4 رکورد (40.0%)
#    - ستون 'comment_count': 4 رکورد (40.0%)
#    - ستون 'avg_like_ratio': 4 رکورد (40.0%)
#    - ستون 'avg_sentiment': 4 رکورد (40.0%)
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_product_top_products.parquet
# 📏 ابعاد: 10 سطر و 25 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'product_id_comment': 5 رکورد (50.0%)
#    - ستون 'avg_rate': 5 رکورد (50.0%)
#    - ستون 'comment_count': 5 رکورد (50.0%)
#    - ستون 'avg_like_ratio': 5 رکورد (50.0%)
#    - ستون 'avg_sentiment': 5 رکورد (50.0%)
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_product_top_revenue_products.parquet
# 📏 ابعاد: 10 سطر و 28 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'product_id_comment': 10 رکورد (100.0%)
#    - ستون 'avg_rate': 10 رکورد (100.0%)
#    - ستون 'comment_count': 10 رکورد (100.0%)
#    - ستون 'avg_like_ratio': 10 رکورد (100.0%)
#    - ستون 'avg_sentiment': 10 رکورد (100.0%)
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_time_daily_trend.parquet
# 📏 ابعاد: 31 سطر و 1 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
# 🔁 تعداد 1 ردیف کاملاً تکراری یافت شد!
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_time_hourly_activity.parquet
# 📏 ابعاد: 24 سطر و 1 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_time_purchase_by_hour.parquet
# 📏 ابعاد: 24 سطر و 1 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_user_segment_heavy_users.parquet
# 📏 ابعاد: 2,450 سطر و 5 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_user_segment_high_conversion_users.parquet
# 📏 ابعاد: 10 سطر و 5 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_user_segment_low_engagement_users.parquet
# 📏 ابعاد: 5 سطر و 5 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: Feature_KPI_output / product_behavior.parquet
# 📏 ابعاد: 720,736 سطر و 6 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: Feature_KPI_output / product_master.parquet
# 📏 ابعاد: 948,352 سطر و 25 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'Category2': 181,346 رکورد (19.1%)
#    - ستون 'Seller': 174 رکورد (0.0%)
#    - ستون 'product_id': 227,616 رکورد (24.0%)
#    - ستون 'is_view': 227,616 رکورد (24.0%)
#    - ستون 'is_cart': 227,616 رکورد (24.0%)
#    - ستون 'is_purchase': 227,616 رکورد (24.0%)
#    - ستون 'conversion_rate': 227,616 رکورد (24.0%)
#    - ستون 'drop_off_rate': 227,616 رکورد (24.0%)
#    - ستون 'product_id_comment': 616,753 رکورد (65.0%)
#    - ستون 'avg_rate': 616,753 رکورد (65.0%)
#    - ستون 'comment_count': 616,753 رکورد (65.0%)
#    - ستون 'avg_like_ratio': 616,753 رکورد (65.0%)
#    - ستون 'avg_sentiment': 616,753 رکورد (65.0%)
#
# 📄 گزارش فایل: Feature_KPI_output / user_behavior_enriched.parquet
# 📏 ابعاد: 3,750,416 سطر و 16 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
# ❌ خطای منطقی: 328,291 رکورد، خرید بیشتر از بازدید دارند!
# ❌ خطای منطقی: 119,087 رکورد با event_type ناشناخته!
#
# 📄 گزارش فایل: Feature_KPI_output / user_features.parquet
# 📏 ابعاد: 63,000 سطر و 5 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# ===========================================================================
# 📂 در حال بازرسی پوشه: Cleaned_output
# ===========================================================================
#
# 📄 گزارش فایل: digikala-comments_parts / part_0000.parquet
# 📏 ابعاد: 50,000 سطر و 17 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'title': 24,693 رکورد (49.4%)
#    - ستون 'body': 6 رکورد (0.0%)
#    - ستون 'created_at': 1,695 رکورد (3.4%)
#    - ستون 'recommendation_status': 7,530 رکورد (15.1%)
#    - ستون 'advantages': 44,665 رکورد (89.3%)
#    - ستون 'disadvantages': 47,318 رکورد (94.6%)
#    - ستون 'seller_title': 2,410 رکورد (4.8%)
#    - ستون 'seller_code': 2,410 رکورد (4.8%)
#    - ستون 'true_to_size_rate': 49,755 رکورد (99.5%)
#
# 📄 گزارش فایل: digikala-products_parts / part_0000.parquet
# 📏 ابعاد: 50,000 سطر و 14 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'Category2': 4,945 رکورد (9.9%)
#    - ستون 'Seller': 6 رکورد (0.0%)
#
# 📄 گزارش فایل: user_behavior_logs_parts / part_0000.parquet
# 📏 ابعاد: 50,000 سطر و 8 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
# ❌ خطای منطقی: 1,631 رکورد با event_type ناشناخته!
#
# 🎉 اسکنر کیفیت داده‌ها کار خود را با موفقیت به پایان رساند!

# %%
#برای اینکه ببینیم ایونت هامون چیان باتوجه به اینکه خطای بررسی کیفیت داده مون نشون داد یه ایونت جا مونده

import pandas as pd
from pathlib import Path

# خواندن فایل لاگ رفتار کاربران
# (از پوشه Feature_KPI_output)
df_logs = pd.read_parquet(
    "../Dataset/Feature_KPI_output/user_behavior_enriched.parquet"
)

# نمایش تعداد هر نوع رویداد موجود در ستون event_type
print(
    df_logs["event_type"].value_counts(dropna=False)
)
# Out:
# event_type
# view                2706875
# add_to_cart          596163
# purchase             328291
# remove_from_cart     119087
# Name: count, dtype: int64

# %%
#باتوجه به خروجی انالیز کیفیت داده میخوایم ببینیم واقعا محصولی هست که خریدش بیشتر از ویو هاش باشه یا نه


import pandas as pd
from pathlib import Path

# خواندن جدول ویژگی محصولات
# (یا جدول نهایی df_golden در صورت استفاده)
df_products = pd.read_parquet(
    "../Dataset/Feature_KPI_output/product_master.parquet"
)

# بررسی وجود ستون‌های مورد نیاز
if (
    "is_view" in df_products.columns
    and "is_purchase" in df_products.columns
):

    # محصولاتی که تعداد خریدشان از تعداد بازدید بیشتر است
    anomaly_products = df_products[
        df_products["is_purchase"] > df_products["is_view"]
    ]

    print(f"📊 تعداد کل محصولات بررسی شده: {len(df_products):,}")
    print(
        f"❌ تعداد محصولاتی که خرید بیشتر از بازدید داشتند: {len(anomaly_products):,}\n"
    )

    if not anomaly_products.empty:
        print("👀 نمونه‌ای از این محصولات:")

        # ستون‌هایی که می‌خواهیم نمایش دهیم
        cols_to_show = [
            "id",
            "title_fa",
            "is_view",
            "is_purchase",
            "conversion_rate",
        ]

        # فقط ستون‌هایی که واقعاً در جدول وجود دارند
        available_cols = [
            col
            for col in cols_to_show
            if col in anomaly_products.columns
        ]

        print(
            anomaly_products[available_cols]
            .head(10)
            .to_string(index=False)
        )

    else:
        print("✅ هیچ محصولی پیدا نشد که خرید آن بیشتر از بازدید باشد.")

else:
    print(
        "⚠️ ستون‌های 'is_view' یا 'is_purchase' در این فایل یافت نشدند."
    )
# Out:
# 📊 تعداد کل محصولات بررسی شده: 948,352
# ❌ تعداد محصولاتی که خرید بیشتر از بازدید داشتند: 0
#
# ✅ هیچ محصولی پیدا نشد که خرید آن بیشتر از بازدید باشد.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# مسیر اصلی دیتاست (در روت پروژه)
dataset_dir = Path("../Dataset")

target_folders = [
    "ABSA_KPI",
    "Feature_KPI_output",
    "Cleaned_output",
]

print("🚀 شروع اسکن جامع کیفیت داده‌ها (Data Quality Auto-Scanner)...\n")

for folder_name in target_folders:
    folder_path = dataset_dir / folder_name

    if not folder_path.exists():
        continue

    print("\n" + "=" * 75)
    print(f"📂 در حال بازرسی پوشه: {folder_name}")
    print("=" * 75)

    # پیدا کردن تمام فایل‌های Parquet
    parquet_files = list(folder_path.rglob("*.parquet"))

    # برای جلوگیری از طولانی شدن خروجی در پوشه‌های پارت‌بندی‌شده،
    # فقط part_0000.parquet بررسی می‌شود.
    for file_path in parquet_files:

        if (
            "part_" in file_path.name
            and file_path.name != "part_0000.parquet"
        ):
            continue

        try:
            df = pd.read_parquet(file_path)

            if df.empty:
                print(
                    f"⚠️ فایل {file_path.parent.name}/{file_path.name} کاملاً خالی است!"
                )
                continue

            print(f"\n📄 گزارش فایل: {file_path.parent.name} / {file_path.name}")
            print(f"📏 ابعاد: {df.shape[0]:,} سطر و {df.shape[1]} ستون")

            # =====================================================
            # 1. بررسی مقادیر گمشده (Null / NaN)
            # =====================================================
            missing_stats = df.isna().sum()
            missing_cols = missing_stats[missing_stats > 0]

            if not missing_cols.empty:
                print("🚨 مقادیر گمشده (Null):")

                for col, count in missing_cols.items():
                    percent = (count / len(df)) * 100
                    print(
                        f"   - ستون '{col}': {count:,} رکورد ({percent:.1f}%)"
                    )
            else:
                print("✅ هیچ مقدار گمشده‌ای وجود ندارد.")

            # =====================================================
            # 2. بررسی ردیف‌های کاملاً تکراری
            # =====================================================
            duplicate_count = df.duplicated().sum()

            if duplicate_count > 0:
                print(
                    f"🔁 تعداد {duplicate_count:,} ردیف کاملاً تکراری یافت شد!"
                )

            # =====================================================
            # 3. بررسی مقادیر بی‌نهایت (Infinity)
            # =====================================================
            numeric_cols = df.select_dtypes(include=[np.number]).columns

            for col in numeric_cols:
                inf_count = np.isinf(df[col]).sum()

                if inf_count > 0:
                    print(
                        f"♾️ هشدار: ستون '{col}' دارای {inf_count:,} مقدار بی‌نهایت است!"
                    )

            # =====================================================
            # 4. بررسی قوانین منطقی (Logical Checks)
            # =====================================================

            # خرید نباید بیشتر از بازدید باشد
            if (
                "is_purchase" in df.columns
                and "is_view" in df.columns
            ):
                invalid_funnel = df[
                    df["is_purchase"] > df["is_view"]
                ]

                if not invalid_funnel.empty:
                    print(
                        f"❌ خطای منطقی: {len(invalid_funnel):,} رکورد، خرید بیشتر از بازدید دارند!"
                    )

            # امتیاز محصولات باید بین 0 تا 100 باشد
            if "Rate" in df.columns:
                invalid_product_rate = df[
                    (df["Rate"] < 0)
                    | (df["Rate"] > 100)
                ]

                if not invalid_product_rate.empty:
                    print(
                        f"❌ خطای منطقی: {len(invalid_product_rate):,} محصول با امتیاز نامعتبر (خارج از بازه 0 تا 100)!"
                    )

            # امتیاز کامنت‌ها باید بین 0 تا 5 باشد
            if "rate" in df.columns:
                invalid_comment_rate = df[
                    (df["rate"] < 0)
                    | (df["rate"] > 5)
                ]

                if not invalid_comment_rate.empty:
                    print(
                        f"❌ خطای منطقی: {len(invalid_comment_rate):,} کامنت با امتیاز نامعتبر (خارج از بازه 0 تا 5)!"
                    )

            # قیمت نباید منفی باشد
            if "Price" in df.columns:
                invalid_price = df[df["Price"] < 0]

                if not invalid_price.empty:
                    print(
                        f"❌ خطای منطقی: {len(invalid_price):,} محصول با قیمت منفی یافت شد!"
                    )

            # بررسی event_type
            if "event_type" in df.columns:
                valid_events = [
                    "view",
                    "add_to_cart",
                    "purchase",
                    "remove_from_cart",
                ]

                invalid_events = df[
                    ~df["event_type"].isin(valid_events)
                ]

                if not invalid_events.empty:
                    print(
                        f"❌ خطای منطقی: {len(invalid_events):,} رکورد با event_type ناشناخته!"
                    )

        except Exception as e:
            print(f"⚠️ خطا در پردازش {file_path.name}: {e}")

print("\n🎉 اسکنر کیفیت داده‌ها کار خود را با موفقیت به پایان رساند!")
# Out:
# 🚀 شروع اسکن جامع کیفیت داده‌ها (Data Quality Auto-Scanner)...
#
#
# ===========================================================================
# 📂 در حال بازرسی پوشه: ABSA_KPI
# ===========================================================================
#
# 📄 گزارش فایل: ABSA_KPI / aspect_frequency.parquet
# 📏 ابعاد: 255,076 سطر و 2 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: ABSA_KPI / aspect_kpi.parquet
# 📏 ابعاد: 255,076 سطر و 6 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: ABSA_KPI / brand_kpi.parquet
# 📏 ابعاد: 6,641 سطر و 6 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: ABSA_KPI / category_kpi.parquet
# 📏 ابعاد: 195 سطر و 6 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: ABSA_KPI / product_aspect_kpi.parquet
# 📏 ابعاد: 2,129,962 سطر و 7 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: ABSA_KPI / product_kpi.parquet
# 📏 ابعاد: 331,599 سطر و 8 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'top_aspect': 60,005 رکورد (18.1%)
#    - ستون 'worst_aspect': 169,050 رکورد (51.0%)
#
# 📄 گزارش فایل: ABSA_KPI / product_master_absa.parquet
# 📏 ابعاد: 948,352 سطر و 16 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'Category2': 181,346 رکورد (19.1%)
#    - ستون 'positive': 616,753 رکورد (65.0%)
#    - ستون 'negative': 616,753 رکورد (65.0%)
#    - ستون 'neutral': 616,753 رکورد (65.0%)
#    - ستون 'sentiment_score': 616,753 رکورد (65.0%)
#    - ستون 'total_comments': 616,753 رکورد (65.0%)
#    - ستون 'top_aspect': 676,758 رکورد (71.4%)
#    - ستون 'worst_aspect': 785,803 رکورد (82.9%)
#
# 📄 گزارش فایل: ABSA_KPI / sentiment_distribution.parquet
# 📏 ابعاد: 3 سطر و 2 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# ===========================================================================
# 📂 در حال بازرسی پوشه: Feature_KPI_output
# ===========================================================================
#
# 📄 گزارش فایل: Feature_KPI_output / city_features.parquet
# 📏 ابعاد: 20 سطر و 3 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: Feature_KPI_output / comment_features.parquet
# 📏 ابعاد: 331,599 سطر و 5 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: Feature_KPI_output / feature_table.parquet
# 📏 ابعاد: 3,750,416 سطر و 63 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'Category2': 271,786 رکورد (7.2%)
#    - ستون 'Seller': 558 رکورد (0.0%)
#    - ستون 'product_id_comment': 2,492,430 رکورد (66.5%)
#    - ستون 'avg_rate': 2,492,430 رکورد (66.5%)
#    - ستون 'comment_count': 2,492,430 رکورد (66.5%)
#    - ستون 'avg_like_ratio': 2,492,430 رکورد (66.5%)
#    - ستون 'avg_sentiment': 2,492,430 رکورد (66.5%)
# ❌ خطای منطقی: 328,291 رکورد، خرید بیشتر از بازدید دارند!
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_category_top_categories.parquet
# 📏 ابعاد: 228 سطر و 1 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
# 🔁 تعداد 77 ردیف کاملاً تکراری یافت شد!
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_product_best_funnel_products.parquet
# 📏 ابعاد: 10 سطر و 33 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'product_id_comment': 4 رکورد (40.0%)
#    - ستون 'avg_rate': 4 رکورد (40.0%)
#    - ستون 'comment_count': 4 رکورد (40.0%)
#    - ستون 'avg_like_ratio': 4 رکورد (40.0%)
#    - ستون 'avg_sentiment': 4 رکورد (40.0%)
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_product_high_remove_rate_products.parquet
# 📏 ابعاد: 10 سطر و 34 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'product_id_comment': 8 رکورد (80.0%)
#    - ستون 'avg_rate': 8 رکورد (80.0%)
#    - ستون 'comment_count': 8 رکورد (80.0%)
#    - ستون 'avg_like_ratio': 8 رکورد (80.0%)
#    - ستون 'avg_sentiment': 8 رکورد (80.0%)
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_product_most_removed_products.parquet
# 📏 ابعاد: 10 سطر و 34 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'Category2': 1 رکورد (10.0%)
#    - ستون 'product_id_comment': 4 رکورد (40.0%)
#    - ستون 'avg_rate': 4 رکورد (40.0%)
#    - ستون 'comment_count': 4 رکورد (40.0%)
#    - ستون 'avg_like_ratio': 4 رکورد (40.0%)
#    - ستون 'avg_sentiment': 4 رکورد (40.0%)
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_product_top_products.parquet
# 📏 ابعاد: 10 سطر و 31 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'product_id_comment': 5 رکورد (50.0%)
#    - ستون 'avg_rate': 5 رکورد (50.0%)
#    - ستون 'comment_count': 5 رکورد (50.0%)
#    - ستون 'avg_like_ratio': 5 رکورد (50.0%)
#    - ستون 'avg_sentiment': 5 رکورد (50.0%)
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_product_top_revenue_products.parquet
# 📏 ابعاد: 10 سطر و 34 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'product_id_comment': 10 رکورد (100.0%)
#    - ستون 'avg_rate': 10 رکورد (100.0%)
#    - ستون 'comment_count': 10 رکورد (100.0%)
#    - ستون 'avg_like_ratio': 10 رکورد (100.0%)
#    - ستون 'avg_sentiment': 10 رکورد (100.0%)
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_product_worst_cart_products.parquet
# 📏 ابعاد: 10 سطر و 34 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'product_id_comment': 7 رکورد (70.0%)
#    - ستون 'avg_rate': 7 رکورد (70.0%)
#    - ستون 'comment_count': 7 رکورد (70.0%)
#    - ستون 'avg_like_ratio': 7 رکورد (70.0%)
#    - ستون 'avg_sentiment': 7 رکورد (70.0%)
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_time_daily_trend.parquet
# 📏 ابعاد: 31 سطر و 1 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
# 🔁 تعداد 1 ردیف کاملاً تکراری یافت شد!
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_time_hourly_activity.parquet
# 📏 ابعاد: 24 سطر و 1 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_time_purchase_by_hour.parquet
# 📏 ابعاد: 24 سطر و 1 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_user_segment_heavy_users.parquet
# 📏 ابعاد: 2,450 سطر و 14 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_user_segment_high_conversion_users.parquet
# 📏 ابعاد: 10 سطر و 14 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_user_segment_high_remove_users.parquet
# 📏 ابعاد: 436 سطر و 14 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: Feature_KPI_output / kpi_user_segment_low_engagement_users.parquet
# 📏 ابعاد: 5 سطر و 14 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: Feature_KPI_output / product_behavior.parquet
# 📏 ابعاد: 720,736 سطر و 10 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 📄 گزارش فایل: Feature_KPI_output / product_master.parquet
# 📏 ابعاد: 948,352 سطر و 31 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'Category2': 181,346 رکورد (19.1%)
#    - ستون 'Seller': 174 رکورد (0.0%)
#    - ستون 'product_id': 227,616 رکورد (24.0%)
#    - ستون 'is_view': 227,616 رکورد (24.0%)
#    - ستون 'is_cart': 227,616 رکورد (24.0%)
#    - ستون 'is_remove': 227,616 رکورد (24.0%)
#    - ستون 'is_purchase': 227,616 رکورد (24.0%)
#    - ستون 'conversion_rate': 227,616 رکورد (24.0%)
#    - ستون 'drop_off_rate': 227,616 رکورد (24.0%)
#    - ستون 'remove_rate': 227,616 رکورد (24.0%)
#    - ستون 'cart_abandon_rate': 227,616 رکورد (24.0%)
#    - ستون 'remove_to_cart_ratio': 227,616 رکورد (24.0%)
#    - ستون 'product_id_comment': 616,753 رکورد (65.0%)
#    - ستون 'avg_rate': 616,753 رکورد (65.0%)
#    - ستون 'comment_count': 616,753 رکورد (65.0%)
#    - ستون 'avg_like_ratio': 616,753 رکورد (65.0%)
#    - ستون 'avg_sentiment': 616,753 رکورد (65.0%)
#
# 📄 گزارش فایل: Feature_KPI_output / user_behavior_enriched.parquet
# 📏 ابعاد: 3,750,416 سطر و 17 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
# ❌ خطای منطقی: 328,291 رکورد، خرید بیشتر از بازدید دارند!
#
# 📄 گزارش فایل: Feature_KPI_output / user_features.parquet
# 📏 ابعاد: 63,000 سطر و 14 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# ===========================================================================
# 📂 در حال بازرسی پوشه: Cleaned_output
# ===========================================================================
#
# 📄 گزارش فایل: digikala-comments_parts / part_0000.parquet
# 📏 ابعاد: 50,000 سطر و 17 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'title': 24,693 رکورد (49.4%)
#    - ستون 'body': 6 رکورد (0.0%)
#    - ستون 'created_at': 1,695 رکورد (3.4%)
#    - ستون 'recommendation_status': 7,530 رکورد (15.1%)
#    - ستون 'advantages': 44,665 رکورد (89.3%)
#    - ستون 'disadvantages': 47,318 رکورد (94.6%)
#    - ستون 'seller_title': 2,410 رکورد (4.8%)
#    - ستون 'seller_code': 2,410 رکورد (4.8%)
#    - ستون 'true_to_size_rate': 49,755 رکورد (99.5%)
#
# 📄 گزارش فایل: digikala-products_parts / part_0000.parquet
# 📏 ابعاد: 50,000 سطر و 14 ستون
# 🚨 مقادیر گمشده (Null):
#    - ستون 'Category2': 4,945 رکورد (9.9%)
#    - ستون 'Seller': 6 رکورد (0.0%)
#
# 📄 گزارش فایل: user_behavior_logs_parts / part_0000.parquet
# 📏 ابعاد: 50,000 سطر و 8 ستون
# ✅ هیچ مقدار گمشده‌ای وجود ندارد.
#
# 🎉 اسکنر کیفیت داده‌ها کار خود را با موفقیت به پایان رساند!

# %%
import pandas as pd
from pathlib import Path

print("==================================================")
print("👤 بررسی ویژگی‌های پیشرفته اضافه شده به کاربران:")
print("==================================================")
df_user = pd.read_parquet('../Dataset/Feature_KPI_output/user_features.parquet')
# فیلتر کردن کاربرانی که خرید داشته‌اند تا اعداد را واضح‌تر ببینیم
sample_users = df_user[df_user['total_spend'] > 0]
cols_user = [
    'user_id', 'total_spend', 'aov', 'brand_diversity', 
    'category_diversity', 'total_sessions', 'avg_session_depth', 'weekend_activity_ratio'
]
print(sample_users[cols_user].head().to_string())

print("\n==================================================")
print("📦 بررسی ویژگی‌های پیشرفته اضافه شده به محصولات:")
print("==================================================")
df_prod = pd.read_parquet('../Dataset/Feature_KPI_output/product_master.parquet')
# فیلتر کردن محصولاتی که بازدید و کامنت داشته‌اند
sample_prods = df_prod[df_prod['review_engagement_rate'] > 0]
cols_prod = ['id', 'Price', 'min_price_last_month', 'price_drop_ratio', 'review_engagement_rate']
print(sample_prods[cols_prod].head().to_string())

'''
total_spend: مجموع خرج‌کرد مشتری (ارزش کل خریدهای کاربر به تومان).
  aov: میانگین ارزش سبد خرید (Average Order Value - میانگین پولی که کاربر در هر خرید می‌دهد).
  brand_diversity: تنوع برند (تعداد برندهای یکتایی که کاربر از آن‌ها خرید کرده است).
  category_diversity: تنوع دسته‌بندی (تعداد دسته‌بندی‌های مختلفی که کاربر تجربه کرده است).
  total_sessions: تعداد کل نشست‌ها (چند بار کاربر وارد سایت دیجی‌کالا شده و سشن یکتا داشته است).
  avg_session_depth: میانگین عمق نشست (در هر بار ورود به سایت، به طور متوسط چند اکشن مثل کلیک، بازدید یا خرید انجام داده است).
  weekend_activity_ratio: نسبت فعالیت در آخر هفته (چه کسری از کل فعالیت‌های کاربر در روزهای تعطیل بوده است).
  review_engagement_rate: نرخ درگیری نظرات (حاصل تقسیم تعداد کل کامنت‌ها بر تعداد کل بازدیدهای محصول). نشان می‌دهد یک کالا چقدر بحث‌برانگیز یا جذاب بوده است.
  price_drop_ratio: نسبت افت قیمت (میزان افت قیمت فعلی کالا نسبت به کمترین قیمت آن در ماه گذشته). مقادیر منفی (افزایش قیمت) را صفر در نظر گرفتیم تا دقیقاً شکارچیان تخفیف بتوانند از این فیچر استفاده کنند.

'''
# Out:
# ==================================================
# 👤 بررسی ویژگی‌های پیشرفته اضافه شده به کاربران:
# ==================================================
#    user_id  total_spend           aov  brand_diversity  category_diversity  total_sessions  avg_session_depth  weekend_activity_ratio
# 0   100000  114401000.0  1.271122e+07              8.0                 8.0              17           4.764706                0.185185
# 1   100001   14613800.0  2.435633e+06              4.0                 3.0              15           4.466667                0.134328
# 2   100002   56969100.0  7.121138e+06              5.0                 7.0              16           5.187500                0.590361
# 3   100003   52721500.0  1.054430e+07              4.0                 5.0               7           4.571429                0.531250
# 4   100004    8620000.0  4.310000e+06              2.0                 2.0               8           3.625000                0.310345
#
# ==================================================
# 📦 بررسی ویژگی‌های پیشرفته اضافه شده به محصولات:
# ==================================================
#         id      Price  min_price_last_month  price_drop_ratio  review_engagement_rate
# 0  7096438   634800.0                   0.0               0.0                1.999980
# 1  2845119   818800.0                   0.0               0.0               63.999680
# 2  6117745   920000.0                   0.0               0.0                2.999993
# 4  6335462  1530000.0                   0.0               0.0                4.499989
# 5  6335562  1521000.0                   0.0               0.0                2.499988
